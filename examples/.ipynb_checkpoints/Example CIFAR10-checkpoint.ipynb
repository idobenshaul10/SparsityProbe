# %%
# %cd ..
import DL_Layer_Analysis
# %cd examples
# Out:
# /home/ido/projects/SparsityProbe
# /home/ido/projects/SparsityProbe/examples

# %% [markdown]
# # Computing $\alpha$-Scores on CIFAR10 Dataset
# In this example, we will show how to compute the $\alpha$-scores on a trained CIFAR10 network.
# We use a Resnet18 trained on CIFAR10.
# Pretrained Resnet18 taken from https://github.com/huyvnphan/PyTorch_CIFAR10 **(Check it out!)**.

# %%
from DL_Layer_Analysis.clustering import *
from DL_Layer_Analysis.DL_smoothness import *
from utils.utils import *
import pickle
loaded_example_args = pickle.load(open(os.path.join('cifar10', 'args.p'), "rb"))
# %matplotlib inline

# %% [markdown]
# ## Loading params for Smoothness Script

# %%
'''print saved args'''
loaded_example_args
# Out:
# Namespace(batch_size=1024, calc_test=True, checkpoint_path=None, checkpoints_folder='cifar10/outputs', depth=20, env_name='cifar10_env', epsilon_1=0.1, feature_dimension=100000, feature_dimenstion=1000, low_range_epsilon=0.4, output_folder='cifar10/outputs', seed=1079, trees=5, use_clustering=False)

# %%
'''init number of trees, epsilons, and dim reduction threshold'''
loaded_example_args.trees = 5
loaded_example_args.epsilon_1 = 0.1
loaded_example_args.epsilon_2 = 0.4
loaded_example_args.seed = 1079
loaded_example_args.feature_dimension = 1000

# %% [markdown]
# ## Fetching the Loaders, Datasets, and Layers
# Following the **env_name** arg, the datasets, model, and model layers are loaded. For more on this, check out **environements/cifar10_env.py**.

# %%
'''init the model, along with the test loader, and layers to run analysis on'''
args, model, dataset, test_dataset, layers, data_loader =  init_params(args=loaded_example_args)
# Out:
# Namespace(batch_size=1024, calc_test=True, checkpoint_path=None, checkpoints_folder='cifar10/outputs', depth=20, env_name='cifar10_env', epsilon_1=0.1, epsilon_2=0.4, feature_dimension=1000, feature_dimenstion=1000, low_range_epsilon=0.4, output_folder='cifar10/outputs', seed=1079, trees=5, use_clustering=False, use_cuda=True)
# Files already downloaded and verified
# Files already downloaded and verified

# %%
'''outputs written to...'''
loaded_example_args.output_folder
# Out:
# 'cifar10/outputs'

# %% [markdown]
# ## Running Sparsity Probe on all given layers

# %%
'''run sparsity analysis algorithm with given arguments'''
# only_umap used when we only want the visualization
args.only_umap = False
# When we want to comapre to clustering metrics, use args.use_clustering = True
args.use_clustering = True
# Run sparsity on the CIFAR10 pretrained example
sparsity_run_output = run_smoothness_analysis(args, model, dataset, test_dataset, layers, data_loader)
# Out:
# 100%|██████████| 49/49 [00:06<00:00,  7.83it/s]
#   2%|▏         | 1/49 [00:00<00:06,  7.05it/s]
# There are 8 layers!
# LAYER -1, type:layer
# 100%|██████████| 49/49 [00:05<00:00,  8.67it/s]
# computing TruncatedSVD, X:torch.Size([50000, 3072]), output_dimension:1000
# TruncatedSVD took 44.64956521987915
# X.shape:(50000, 1000), Y shape:(50000, 1)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 5
# building tree 2 of 5
# building tree 3 of 5
# building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   47.0s remaining:   31.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   48.8s finished
# 100%|██████████| 170/170 [00:00<00:00, 644.50it/s]
# ALPHA for LAYER -1 is 0.15076959292991607
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.04063624023526627
# MI_score:0.07697876636894073
# homogeneity_score:0.07673375333637594
# completeness:0.07788690615803691
# FMI:0.13971997823187632
# Fitting umap
#   0%|          | 0/49 [00:00<?, ?it/s]
# Done fitting umap
# layers: 4 2 1
# LAYER 0, type:layer
# 100%|██████████| 49/49 [00:07<00:00,  6.55it/s]
# computing TruncatedSVD, X:(50000, 16384), output_dimension:1000
# TruncatedSVD took 208.92283129692078
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 5building tree 2 of 5
#
# building tree 3 of 5
# building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   38.9s remaining:   26.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   39.1s finished
# 100%|██████████| 170/170 [00:00<00:00, 560.29it/s]
# ALPHA for LAYER 0 is 0.14788542234622276
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.09719231215091839
# MI_score:0.18201100664024467
# homogeneity_score:0.17959912912000006
# completeness:0.18508999870195597
# FMI:0.19347328854539153
# Fitting umap
#   0%|          | 0/49 [00:00<?, ?it/s]
# Done fitting umap
# layers: 4 2 2
# LAYER 1, type:layer
# 100%|██████████| 49/49 [00:06<00:00,  7.40it/s]
# computing TruncatedSVD, X:(50000, 16384), output_dimension:1000
# TruncatedSVD took 213.2205946445465
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 5building tree 2 of 5
# building tree 3 of 5
# building tree 4 of 5
#
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   42.2s remaining:   28.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   43.4s finished
# 100%|██████████| 170/170 [00:00<00:00, 654.21it/s]
# ALPHA for LAYER 1 is 0.1516375328333428
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.10268737255930185
# MI_score:0.18181405298650075
# homogeneity_score:0.17701463292166272
# completeness:0.18750810328182244
# FMI:0.20334035834763226
# Fitting umap
#   0%|          | 0/49 [00:00<?, ?it/s]
# Done fitting umap
# layers: 4 2 3
# LAYER 2, type:layer
# 100%|██████████| 49/49 [00:06<00:00,  7.77it/s]
# computing TruncatedSVD, X:(50000, 8192), output_dimension:1000
# TruncatedSVD took 100.47278666496277
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# building tree 1 of 5building tree 2 of 5
#
# building tree 3 of 5
# building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   40.5s remaining:   27.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   41.7s finished
# 100%|██████████| 170/170 [00:00<00:00, 785.97it/s]
# ALPHA for LAYER 2 is 0.16273064965291867
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.18229841275347924
# MI_score:0.29326966456480535
# homogeneity_score:0.28639600260881803
# completeness:0.3010171469027513
# FMI:0.2726317073503763
# Fitting umap
#   2%|▏         | 1/49 [00:00<00:05,  8.29it/s]
# Done fitting umap
# layers: 4 2 4
# LAYER 3, type:layer
# 100%|██████████| 49/49 [00:05<00:00,  9.65it/s]
# computing TruncatedSVD, X:(50000, 8192), output_dimension:1000
# TruncatedSVD took 59.54507899284363
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# building tree 1 of 5building tree 2 of 5
# building tree 3 of 5
# building tree 4 of 5
#
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   34.6s remaining:   23.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   34.9s finished
# 100%|██████████| 170/170 [00:00<00:00, 881.52it/s]
# ALPHA for LAYER 3 is 0.16971454715108755
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.2598799966998299
# MI_score:0.36634181139078054
# homogeneity_score:0.3598247122744921
# completeness:0.3735709592726761
# FMI:0.3402062432254994
# Fitting umap
#   2%|▏         | 1/49 [00:00<00:05,  8.44it/s]
# Done fitting umap
# layers: 4 2 5
# LAYER 4, type:layer
# 100%|██████████| 49/49 [00:05<00:00,  9.40it/s]
# computing TruncatedSVD, X:(50000, 4096), output_dimension:1000
# TruncatedSVD took 33.324687242507935
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# building tree 1 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   41.2s remaining:   27.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   42.1s finished
# 100%|██████████| 170/170 [00:00<00:00, 2091.37it/s]
# ALPHA for LAYER 4 is 0.23240047316461565
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.61832358157081
# MI_score:0.7042641403779923
# homogeneity_score:0.6960690437360276
# completeness:0.7128702280890697
# FMI:0.6597307041257476
# Fitting umap
#   2%|▏         | 1/49 [00:00<00:05,  9.13it/s]
# Done fitting umap
# layers: 4 2 6
# LAYER 5, type:layer
# 100%|██████████| 49/49 [00:05<00:00,  9.59it/s]
# computing TruncatedSVD, X:(50000, 4096), output_dimension:1000
# TruncatedSVD took 33.98578977584839
# after dim reduction
# X.shape:(50000, 1000), Y shape:(50000, 1)
# building tree 1 of 5building tree 2 of 5
# building tree 3 of 5
#
# building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:   43.8s remaining:   29.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   45.6s finished
# 100%|██████████| 170/170 [00:00<00:00, 3813.51it/s]
# ALPHA for LAYER 5 is 0.28196860433292326
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.7866415633058121
# MI_score:0.8325071106464148
# homogeneity_score:0.826820666569468
# completeness:0.8383926828311249
# FMI:0.8090466653090624
# Fitting umap
#   2%|▏         | 1/49 [00:00<00:05,  8.77it/s]
# Done fitting umap
# layers: 4 2 7
# LAYER 6, type:layer
# 100%|██████████| 49/49 [00:05<00:00,  9.52it/s]
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# X.shape:(50000, 512), Y shape:(50000, 1)
# building tree 1 of 5building tree 2 of 5
# building tree 3 of 5
#
# building tree 4 of 5
# building tree 5 of 5
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:    6.1s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.2s finished
# 100%|██████████| 170/170 [00:00<00:00, 57097.35it/s]
# ALPHA for LAYER 6 is 0.6385535167709897
# Fitting k means with k=10
# START clustering statistics
# DONE clustering statistics
# adj_rand:0.9972926692466821
# MI_score:0.9956061349614815
# homogeneity_score:0.9956075895777268
# completeness:0.9956077729292163
# FMI:0.9975633537039685
# Fitting umap
# Done fitting umap
# layers: 4 2 8
# save_path:cifar10/outputs/result.png

# %% [markdown]
# ## Plotting the $\alpha$-Scores vs. Clustering Metrics

# %%
from DL_Layer_Analysis.plot_DL_json_results import plot_layers
# Plot alpha smoothness through the pochs, and compare to clustering scores
plot_layers(args.checkpoints_folder, plot_test=True, add_fill=False, use_clustering=True)
# Out:
# error:list index out of range
# [0.15076959292991607, 0.14788542234622276, 0.1516375328333428, 0.16273064965291867, 0.16971454715108755, 0.23240047316461565, 0.28196860433292326, 0.6385535167709897]
